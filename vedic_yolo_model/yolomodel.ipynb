# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ultralytics
#   Downloading ultralytics-8.4.41-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from ultralytics) (2.4.4)
# Collecting matplotlib>=3.3.0 (from ultralytics)
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from ultralytics) (2.33.1)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Downloading scipy-1.17.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: torch>=1.8.0 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from ultralytics) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from ultralytics) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from ultralytics) (7.2.2)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.40.0-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.0->ultralytics)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.0->ultralytics)
#   Downloading fonttools-4.62.1-cp312-cp312-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from matplotlib>=3.3.0->ultralytics) (26.1)
# Collecting pyparsing>=3 (from matplotlib>=3.3.0->ultralytics)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.40.0 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.40.0-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests>=2.23.0->ultralytics) (3.12)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from torch>=1.8.0->ultralytics) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.41-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 15.3 MB/s  0:00:00
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 56.3 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 44.0 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl (73 kB)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    --------- ------------------------------ 9.7/40.2 MB 54.9 MB/s eta 0:00:01
#    -------------- ------------------------- 14.9/40.2 MB 39.1 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 65.4 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 54.4 MB/s  0:00:00
# Downloading polars-1.40.0-py3-none-any.whl (828 kB)
#    ---------------------------------------- 0.0/828.0 kB ? eta -:--:--
#    ---------------------------------------- 828.0/828.0 kB 35.4 MB/s  0:00:00
# Downloading polars_runtime_32-1.40.0-cp310-abi3-win_amd64.whl (51.8 MB)
#    ---------------------------------------- 0.0/51.8 MB ? eta -:--:--
#    ---------------- ----------------------- 22.0/51.8 MB 107.2 MB/s eta 0:00:01
#    ------------------------------ --------- 40.1/51.8 MB 98.1 MB/s eta 0:00:01
#    ---------------------------------------- 51.8/51.8 MB 84.7 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading scipy-1.17.1-cp312-cp312-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    -------------------------- ------------- 24.1/36.5 MB 126.9 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 92.8 MB/s  0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: scipy, pyparsing, polars-runtime-32, opencv-python, kiwisolver, fonttools, cycler, contourpy, polars, matplotlib, ultralytics-thop, ultralytics
#
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    ----------------------------------------  0/12 [scipy]
#    --- ------------------------------------  1/12 [pyparsing]
#    --- ------------------------------------  1/12 [pyparsing]
#    --- ------------------------------------  1/12 [pyparsing]
#    ------ ---------------------------------  2/12 [polars-runtime-32]
#    ------ ---------------------------------  2/12 [polars-runtime-32]
#    ------ ---------------------------------  2/12 [polars-runtime-32]
#    ------ ---------------------------------  2/12 [polars-runtime-32]
#    ------ ---------------------------------  2/12 [polars-runtime-32]
#    ------ ---------------------------------  2/12 [polars-runtime-32]
#    ---------- -----------------------------  3/12 [opencv-python]
#    ---------- -----------------------------  3/12 [opencv-python]
#    ---------- -----------------------------  3/12 [opencv-python]
#    ---------- -----------------------------  3/12 [opencv-python]
#    ---------- -----------------------------  3/12 [opencv-python]
#    ---------- -----------------------------  3/12 [opencv-python]
#    ---------- -----------------------------  3/12 [opencv-python]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ---------------- -----------------------  5/12 [fonttools]
#    ----------------------- ----------------  7/12 [contourpy]
#    ----------------------- ----------------  7/12 [contourpy]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    ------------------------------ ---------  9/12 [matplotlib]
#    --------------------------------- ------ 10/12 [ultralytics-thop]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ---------------------------------------- 12/12 [ultralytics]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 opencv-python-4.13.0.92 polars-1.40.0 polars-runtime-32-1.40.0 pyparsing-3.3.2 scipy-1.17.1 ultralytics-8.4.41 ultralytics-thop-2.0.18
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts ultralytics.exe and yolo.exe are installed in 'C:\Users\vedic\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os
import shutil

# ✅ Your actual dataset path
BASE_PATH = r"C:\Users\vedic\OneDrive\Desktop\deep learning\dataset"

# Auto paths
src_images = os.path.join(BASE_PATH, "images")
src_labels = os.path.join(BASE_PATH, "labels")
dst_root = os.path.join(BASE_PATH, "dataset_cls")

splits = ["train", "val"]

print("📁 Using dataset at:", BASE_PATH)

# ✅ Check paths
if not os.path.exists(src_images):
    raise FileNotFoundError(f"Images folder not found: {src_images}")

if not os.path.exists(src_labels):
    raise FileNotFoundError(f"Labels folder not found: {src_labels}")

print("✅ Paths verified\n")

for split in splits:
    img_dir = os.path.join(src_images, split)
    lbl_dir = os.path.join(src_labels, split)

    if not os.path.exists(img_dir):
        print(f"⚠️ Missing: {img_dir}")
        continue

    if not os.path.exists(lbl_dir):
        print(f"⚠️ Missing: {lbl_dir}")
        continue

    print(f"🔄 Processing {split}...")

    for file in os.listdir(img_dir):
        if not file.lower().endswith((".jpg", ".jpeg", ".png")):
            continue

        img_path = os.path.join(img_dir, file)
        label_path = os.path.join(lbl_dir, file.rsplit(".", 1)[0] + ".txt")

        if not os.path.exists(label_path):
            continue

        # Read class ID
        with open(label_path, "r") as f:
            line = f.readline().strip()
            if not line:
                continue
            class_id = line.split()[0]

        # Create class folder
        class_folder = os.path.join(dst_root, split, f"class_{class_id}")
        os.makedirs(class_folder, exist_ok=True)

        # Copy image
        shutil.copy(img_path, os.path.join(class_folder, file))

print("\n✅ Dataset converted successfully → dataset_cls/")
# Out:
# 📁 Using dataset at: C:\Users\vedic\OneDrive\Desktop\deep learning\dataset
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 18
#      14 print("📁 Using dataset at:", BASE_PATH)
#      15
#      16 # ✅ Check paths
#      17 if not os.path.exists(src_images):
# ---> 18     raise FileNotFoundError(f"Images folder not found: {src_images}")
#      19
#      20 if not os.path.exists(src_labels):
#      21     raise FileNotFoundError(f"Labels folder not found: {src_labels}")
#
# FileNotFoundError: Images folder not found: C:\Users\vedic\OneDrive\Desktop\deep learning\dataset\images
