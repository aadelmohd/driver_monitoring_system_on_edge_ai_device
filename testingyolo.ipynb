# %%
import os
from ultralytics import YOLO

# Set your project root folder
PROJECT_PATH = "C:/Users/vedic/OneDrive/Desktop/deep learning"

# Automatically find best.pt
best_model_path = None

for root, dirs, files in os.walk(PROJECT_PATH):
    if "best.pt" in files:
        best_model_path = os.path.join(root, "best.pt")
        break

# Check if found
if best_model_path is None:
    raise FileNotFoundError("best.pt not found in project folder!")

print("Model found at:", best_model_path)

# Load model
model = YOLO(best_model_path)

# Run validation to get accuracy
metrics = model.val(data="dataset")  # make sure 'dataset' folder exists

# Print accuracy
print(f"Top-1 Accuracy: {metrics.top1:.4f}")
print(f"Top-5 Accuracy: {metrics.top5:.4f}")
# Out:
# Model found at: C:/Users/vedic/OneDrive/Desktop/deep learning\runs\classify\runs\classify\distracted_driver\weights\best.pt
# Ultralytics 8.4.41  Python-3.12.10 torch-2.11.0+cpu CPU (Intel Core i7-14650HX)
# YOLOv8n-cls summary (fused): 30 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
# train: C:\Users\vedic\OneDrive\Desktop\deep learning\dataset\train... found 85 images in 2 classes
# val: C:\Users\vedic\OneDrive\Desktop\deep learning\dataset\val... found 122 images in 2 classes
# test: None...
# val: Fast image access  (ping: 0.00.0 ms, read: 185.154.5 MB/s, size: 41.5 KB)
# val: Scanning C:\Users\vedic\OneDrive\Desktop\deep learning\dataset\val... 122 images, 0 corrupt: 100% ━━━━━━━━━━━━ 122/122  0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 8.1it/s 1.0s0.1s
#                    all      0.738          1
# Speed: 0.0ms preprocess, 1.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\vedic\OneDrive\Desktop\deep learning\runs\classify\val
# Top-1 Accuracy: 0.7377
# Top-5 Accuracy: 1.0000
